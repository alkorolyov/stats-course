# %%
import math

import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import rand

# %%
"""
PDF - (np.cos(x) + 1) / (2 * pi) on interval [0, 2*pi]
CDF -
"""
pi = 3.1415926

fig, (ax1, ax2) = plt.subplots(1, 2)

x = np.linspace(0, 2*pi, 100)
pdf = (np.cos(x) + 1) / (2 * pi)
cdf = (np.sin(x) + x) / (2 * pi)
ax1.plot(x, pdf)
ax1.set_title('PDF')
ax2.plot(x, cdf)
ax2.set_title('CDF');

# %%
def x_sinx(x: np.ndarray, n = 7):
    x = x - np.pi
    x_2 = x * x

    # res = np.full_like(x, np.pi)
    # for i in range(3, n + 1):
    #     if i % 2 == 1:
    #         x *= x_2
    #         res += x / math.factorial(n)

    x_3 = x * x_2
    x_5 = x_3 * x_2
    x_7 = x_5 * x_2
    return (np.pi + x_3 / 6 - x_5 / 120
            + x_7 / 5040
            # + x_7 * x_2 / 362880
            )

# %timeit x_sinx(u)
# Out:
# 17.4 ms ± 202 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
x = np.linspace(0, 2 * pi, 100)
y = x_sinx(x) - (np.sin(x) + x)

plt.plot(x, x_sinx(x))
plt.plot(x, (np.sin(x) + x));

# %%
plt.hist(u, density=True);
